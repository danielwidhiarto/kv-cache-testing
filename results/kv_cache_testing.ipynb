# %%
# ==========================================
# Cell 1: Clone / Update Repo & Install
# ==========================================
import os
# %cd /content
if not os.path.exists('kv-cache-testing'):
    # !git clone https://github.com/danielwidhiarto/kv-cache-testing.git
# %cd /content/kv-cache-testing
# !git fetch origin
# !git reset --hard origin/main
# !git pull origin main

# !pip install -q torch transformers accelerate pandas matplotlib sentencepiece protobuf
# Out:
# Cloning into 'kv-cache-testing'...
# remote: Enumerating objects: 294, done.
# remote: Counting objects: 100% (294/294), done.
# remote: Compressing objects: 100% (203/203), done.
# remote: Total 294 (delta 181), reused 198 (delta 85), pack-reused 0 (from 0)
# Receiving objects: 100% (294/294), 20.55 MiB | 18.88 MiB/s, done.
# Resolving deltas: 100% (181/181), done.
# /content/kv-cache-testing/kv-cache-testing

# %%
# !python benchmarks/run_colab_experiment.py \
    --model Qwen/Qwen2.5-7B-Instruct \
    --num-samples 14 \
    --max-cache-size 256 \
    --max-new-tokens 128

# %%
# ==========================================
# Cell 4: Lihat & Analisis Hasil Baru
# ==========================================
import pandas as pd
df = pd.read_csv("results/aes_benchmark.csv")

# Tampilkan kolom penting termasuk skor manusia vs prediksi model
df_summary = df[["policy", "human_score", "predicted_score", "latency_sec", "throughput_tok_sec", "generated_output_preview"]]
display(df_summary.head(20))
# Out:
#            policy  human_score  predicted_score  latency_sec  \
# 0             lru          3.0                3       0.4985
# 1       streaming          3.0                2       0.2295
# 2             h2o          3.0                3       0.2578
# 3            aege          3.0                3       0.3494
# 4   aege_adaptive          3.0                3       0.2981
# 5       FullCache          3.0                2       0.2121
# 6   aege_adaptive          3.0                2       0.3028
# 7            aege          3.0                2       0.2981
# 8             lru          3.0                2       0.2662
# 9       FullCache          3.0                2       0.2137
# 10      streaming          3.0                2       0.2310
# 11            h2o          3.0                2       0.2602
# 12            lru          5.0                4       0.1577
# 13      FullCache          5.0                4       0.1165
# ...

# %%
from google.colab import files

# Download CSV data & Dashboard HTML
files.download("results/aes_benchmark.csv")
files.download("results/dashboard.html")
